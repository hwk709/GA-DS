# %%
import pandas as pd
import matplotlib as plt
import geopandas as gpd
from geopandas import tools
import descartes
import folium
import numpy
import geopy
import seaborn as sns
import plotly.express as px
import datapackage

# %%
gpf = gpd.read_file("ge/asia geo files.json")
gpf.plot()
# Out:
# <AxesSubplot:>

# %%
gpf.plot()
# Out:
# <AxesSubplot:>

# %%
gpf
# Out:
#     scalerank       featurecla  labelrank            sovereignt sov_a3  \
# 0           1  Admin-0 country          2                 China    CH1
# 1           1  Admin-0 country          5                Bhutan    BTN
# 2           1  Admin-0 country          6               Armenia    ARM
# 3           1  Admin-0 country          3           Afghanistan    AFG
# 4           1  Admin-0 country          4               Bahrain    BHR
# 5           1  Admin-0 country          6                Brunei    BRN
# 6           1  Admin-0 country          3            Bangladesh    BGD
# 7           1  Admin-0 country          4  United Arab Emirates    ARE
# 8           1  Admin-0 country          5            Azerbaijan    AZE
# 9           1  Admin-0 country          6       Northern Cyprus    CYN
# 10          1  Admin-0 country          5                Cyprus    CYP
# 11          1  Admin-0 country          5               Georgia    GEO
# ...

# %%
asia
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 5   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 6   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 7   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 8   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 9   FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 10  FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# 11  FeatureCollection  {'type': 'Feature', 'properties': {'scalerank'...
# ...
